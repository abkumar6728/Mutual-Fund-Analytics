# %%
import pandas as pd
import numpy as np

# %%
nav = pd.read_csv("../data/raw/nav_history.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nav = pd.read_csv("../data/raw/nav_history.csv")
#
# File c:\Users\DELL\OneDrive\Desktop\Mutual-Fund-Analytics\.venv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\DELL\OneDrive\Desktop\Mutual-Fund-Analytics\notebooks

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ['01_fund_master.csv', '02_nav_history.csv', '03_aum_by_fund_house.csv', '04_monthly_sip_inflows.csv', '05_category_inflows.csv', '06_industry_folio_count.csv', '07_scheme_performance.csv', '08_investor_transactions.csv', '09_portfolio_holdings.csv', '10_benchmark_indices.csv', 'Axis_Bluechip.csv', 'ICICI_Bluechip.csv', 'Kotak_Bluechip.csv', 'live_nav_20260729.csv', 'Nippon_Large_Cap.csv', 'SBI_Bluechip.csv']

# %%
nav = pd.read_csv("../data/raw/02_nav_history.csv")

# %%
nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
nav.shape
# Out:
# (46000, 3)

# %%
nav.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  object
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
nav["date"] = pd.to_datetime(nav["date"])

# %%
nav.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  datetime64[ns]
#  2   nav        46000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.1 MB

# %%
nav["date"] = pd.to_datetime(nav["date"])

# %%
nav.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  datetime64[ns]
#  2   nav        46000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.1 MB

# %%
nav = nav.sort_values(["amfi_code", "date"])

# %%
nav.head(10)
# Out:
#       amfi_code       date       nav
# 5750     100016 2022-01-03  520.4608
# 5751     100016 2022-01-04  515.0971
# 5752     100016 2022-01-05  521.7239
# 5753     100016 2022-01-06  515.7880
# 5754     100016 2022-01-07  515.1639
# 5755     100016 2022-01-10  510.7136
# 5756     100016 2022-01-11  513.5542
# 5757     100016 2022-01-12  512.3195
# 5758     100016 2022-01-13  510.2445
# 5759     100016 2022-01-14  514.3636

# %%
nav["nav"].isna().sum()
# Out:
# np.int64(0)

# %%
print("Missing NAV values before forward fill:", nav["nav"].isna().sum())

nav["nav"] = nav.groupby("amfi_code")["nav"].ffill()

print("Missing NAV values after forward fill:", nav["nav"].isna().sum())
# Out:
# Missing NAV values before forward fill: 0
# Missing NAV values after forward fill: 0

# %%
nav.duplicated().sum()
# Out:
# np.int64(0)

# %%
(nav["nav"] <= 0).sum()
# Out:
# np.int64(0)

# %%
nav.to_csv("../data/processed/02_nav_history.csv", index=False)

# %%
import os

print(os.listdir("../data/processed"))
# Out:
# ['02_nav_history.csv', 'live_nav.csv']

# %%
transactions = pd.read_csv("../data/raw/08_investor_transactions.csv")

# %%
transactions.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32778 entries, 0 to 32777
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   investor_id         32778 non-null  object
#  1   transaction_date    32778 non-null  object
#  2   amfi_code           32778 non-null  int64
#  3   transaction_type    32778 non-null  object
#  4   amount_inr          32778 non-null  int64
#  5   state               32778 non-null  object
#  6   city                32778 non-null  object
#  7   city_tier           32778 non-null  object
#  8   age_group           32778 non-null  object
#  9   gender              32778 non-null  object
#  10  annual_income_lakh  32778 non-null  float64
#  11  payment_mode        32778 non-null  object
#  12  kyc_status          32778 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 3.3+ MB

# %%
transactions["transaction_type"].value_counts()
# Out:
# transaction_type
# SIP           19716
# Lumpsum        8095
# Redemption     4967
# Name: count, dtype: int64

# %%
transactions["kyc_status"].value_counts()
# Out:
# kyc_status
# Verified    30146
# Pending      2632
# Name: count, dtype: int64

# %%
(transactions["amount_inr"] <= 0).sum()
# Out:
# np.int64(0)

# %%
transactions.to_csv(
    "../data/processed/08_investor_transactions.csv",
    index=False
)

# %%
import os

print(os.listdir("../data/processed"))
# Out:
# ['02_nav_history.csv', '08_investor_transactions.csv', 'live_nav.csv']

# %%
performance = pd.read_csv("../data/raw/07_scheme_performance.csv")

# %%
performance.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   scheme_name         40 non-null     object
#  2   fund_house          40 non-null     object
#  3   category            40 non-null     object
#  4   plan                40 non-null     object
#  5   return_1yr_pct      40 non-null     float64
#  6   return_3yr_pct      40 non-null     float64
#  7   return_5yr_pct      40 non-null     float64
#  8   benchmark_3yr_pct   40 non-null     float64
#  9   alpha               40 non-null     float64
#  10  beta                40 non-null     float64
#  11  sharpe_ratio        40 non-null     float64
#  12  sortino_ratio       40 non-null     float64
#  13  std_dev_ann_pct     40 non-null     float64
#  14  max_drawdown_pct    40 non-null     float64
# ...

# %%
return_columns = [
    "return_1yr_pct",
    "return_3yr_pct",
    "return_5yr_pct"
]

performance[return_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   return_1yr_pct  40 non-null     float64
#  1   return_3yr_pct  40 non-null     float64
#  2   return_5yr_pct  40 non-null     float64
# dtypes: float64(3)
# memory usage: 1.1 KB

# %%
performance[return_columns].isnull().sum()
# Out:
# return_1yr_pct    0
# return_3yr_pct    0
# return_5yr_pct    0
# dtype: int64

# %%
performance[
    (performance["expense_ratio_pct"] < 0.1) |
    (performance["expense_ratio_pct"] > 2.5)
]
# Out:
# Empty DataFrame
# Columns: [amfi_code, scheme_name, fund_house, category, plan, return_1yr_pct, return_3yr_pct, return_5yr_pct, benchmark_3yr_pct, alpha, beta, sharpe_ratio, sortino_ratio, std_dev_ann_pct, max_drawdown_pct, aum_crore, expense_ratio_pct, morningstar_rating, risk_grade]
# Index: []

# %%
anomalies = performance[
    (performance["return_1yr_pct"] > 100) |
    (performance["return_1yr_pct"] < -100) |
    (performance["return_3yr_pct"] > 100) |
    (performance["return_3yr_pct"] < -100) |
    (performance["return_5yr_pct"] > 100) |
    (performance["return_5yr_pct"] < -100)
]

print(anomalies)
# Out:
# Empty DataFrame
# Columns: [amfi_code, scheme_name, fund_house, category, plan, return_1yr_pct, return_3yr_pct, return_5yr_pct, benchmark_3yr_pct, alpha, beta, sharpe_ratio, sortino_ratio, std_dev_ann_pct, max_drawdown_pct, aum_crore, expense_ratio_pct, morningstar_rating, risk_grade]
# Index: []

# %%
performance.to_csv(
    "../data/processed/07_scheme_performance.csv",
    index=False
)

# %%
import sqlalchemy

print(sqlalchemy.__version__)
# Out:
# 2.0.51

# %%
from sqlalchemy import create_engine

engine = create_engine("sqlite:///../bluestock_mf.db")

print("Database created successfully!")
# Out:
# Database created successfully!

# %%
from sqlalchemy import create_engine

engine = create_engine("sqlite:///../bluestock_mf.db")

print(engine)
# Out:
# Engine(sqlite:///../bluestock_mf.db)

# %%
nav.to_sql(
    "nav_history",
    engine,
    if_exists="replace",
    index=False
)

print("Table created!")
# Out:
# Table created!

# %%
import os

print(os.path.exists("../bluestock_mf.db"))
# Out:
# True

# %%
transactions.to_sql(
    "investor_transactions",
    engine,
    if_exists="replace",
    index=False
)

print("investor_transactions loaded!")
# Out:
# investor_transactions loaded!

# %%
performance.to_sql(
    "scheme_performance",
    engine,
    if_exists="replace",
    index=False
)

print("scheme_performance loaded!")
# Out:
# scheme_performance loaded!

# %%
from sqlalchemy import text

with engine.connect() as conn:
    tables = [
        "nav_history",
        "investor_transactions",
        "scheme_performance"
    ]

    for table in tables:
        count = conn.execute(
            text(f"SELECT COUNT(*) FROM {table}")
        ).scalar()

        print(f"{table}: {count} rows")
# Out:
# nav_history: 46000 rows
# investor_transactions: 32778 rows
# scheme_performance: 40 rows

# %%
import pandas as pd
import os

files = [
    "01_fund_master.csv",
    "03_aum_by_fund_house.csv",
    "04_monthly_sip_inflows.csv",
    "05_category_inflows.csv",
    "06_industry_folio_count.csv",
    "09_portfolio_holdings.csv",
    "10_benchmark_indices.csv"
]

for file in files:
    df = pd.read_csv(f"../data/raw/{file}")

    # Basic validation
    print(f"\nProcessing {file}")
    print("Shape:", df.shape)
    print("Missing values:", df.isnull().sum().sum())
    print("Duplicate rows:", df.duplicated().sum())

    # Save to processed
    df.to_csv(f"../data/processed/{file}", index=False)

print("All remaining datasets processed successfully!")
# Out:
# Processing 01_fund_master.csv
# Shape: (40, 15)
# Missing values: 0
# Duplicate rows: 0
#
# Processing 03_aum_by_fund_house.csv
# Shape: (90, 5)
# Missing values: 0
# Duplicate rows: 0
#
# Processing 04_monthly_sip_inflows.csv
# Shape: (48, 6)
# Missing values: 12
# Duplicate rows: 0
#
# Processing 05_category_inflows.csv
# Shape: (144, 3)
# Missing values: 0
# Duplicate rows: 0
#
# Processing 06_industry_folio_count.csv
# Shape: (21, 6)
# Missing values: 0
# Duplicate rows: 0
#
# Processing 09_portfolio_holdings.csv
# Shape: (322, 8)
# Missing values: 0
# Duplicate rows: 0
#
# Processing 10_benchmark_indices.csv
# Shape: (8050, 3)
# Missing values: 0
# Duplicate rows: 0
# All remaining datasets processed successfully!

# %%
sip = pd.read_csv("../data/raw/04_monthly_sip_inflows.csv")

sip.isnull().sum()
# Out:
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# yoy_growth_pct               12
# dtype: int64

# %% [markdown]
# ## Observation: Monthly SIP Inflows Dataset
#
# The `yoy_growth_pct` column contains 12 missing values. These correspond to the first 12 months of the dataset, where Year-over-Year (YoY) growth cannot be calculated because there is no previous year's data available for comparison. These missing values are expected and have been retained.
